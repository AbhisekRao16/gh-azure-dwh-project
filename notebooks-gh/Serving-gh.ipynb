# %%
# %sql
create schema az_dwh_adb_project.gold;

# %%
# %sql
use az_dwh_adb_project.gold;

# %%
# %sql
create  view if not exists az_dwh_adb_project.gold.sale_2015 as 
select * from az_dwh_adb_project.silver.sales_2015;
